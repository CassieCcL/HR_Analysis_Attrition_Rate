# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
employee_df = pd.read_csv("Resources/general_data.csv")

# %%
employee_df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
# Check if some columns are redundant (standard working hours, employee count, Over 18 years old)
print(employee_df["StandardHours"].unique())
print(employee_df["EmployeeCount"].unique())
print(employee_df["Over18"].unique())
# Out:
# [8]
# [1]
# ['Y']

# %% [markdown]
# The above 3 columns only have 1 value, hence they are meaningless for analysis. Will have them removed.

# %%
# Drop 3 meaningless columns
employee_df.drop(["StandardHours", "EmployeeCount", "Over18"], axis=1, inplace=True)

# %%
# Understand CSV

print("Shape of the dataframe:" ,employee_df.shape, "\n")
print("Dataframe has rows:" ,employee_df.shape[0],"\n")
print("Dataframe has columns:" ,employee_df.shape[1],"\n")
print("Columns names are:" ,employee_df.columns,"\n")
print("NULL values in dataframe:","\n")
print(employee_df.isnull().sum())
# employee_df.describe()
# Out:
# Shape of the dataframe: (4410, 29)
#
# Dataframe has rows: 4410
#
# Dataframe has columns: 29
#
# Columns names are: Index(['EmployeeID', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'Gender', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating'],
#       dtype='object')
#
# NULL values in dataframe:
#
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# ...

# %%
# Attrition Ratio in different departments, including different background, sex

# %%
# Which level of employees left the company the most and the personal info
